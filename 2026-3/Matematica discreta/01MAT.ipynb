# %% [markdown]
# ## Primeira aula de matemática discreta
# Fundamentos de Python e seus ambientes (providos pelo Anaconda)

# %% [markdown]
# ![image.png](attachment:d72f61f2-ab2c-402a-81fd-cd225f0b80c0.png)

# %% [markdown]
# $G = \frac{A} {B}$
#
# $F(S) = A\ e^{-st}$
#
# $$ A = B < C < A^{e^{-2\ t}} $$

# %% [markdown]
# adicionando valores e printando na tela

# %%
a = 5 
b = 5
c = 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'int'>

# %% [markdown]
# Importando bibliotemas de raiz quadrada

# %%
# from math import *
import math as mt

# %%
mt.sqrt(2)
# Out:
# 1.4142135623730951

# %%
mt.exp(3)
# Out:
# 20.085536923187668

# %% [markdown]
# Adicionando bibliotecas especificas e conta de matrizes

# %%
import numpy as np

# %%
la = []

# %%
la.append('tomate')
la
# Out:
# [5, 'tomate', 'tomate']

# %%
la.append([1,2,8])
la
# Out:
# [5, 'tomate', 'tomate', [1, 2, 8], [1, 2, 8], [1, 2, 8]]

# %%
l1 = [1, 'maça', [3,8,'vermelho']]
l1
# Out:
# [1, 'maça', [3, 8, 'vermelho']]

# %%
l1[2][1]
# Out:
# 8

# %%
a = {1,8,'latex'}

# %%
a
# Out:
# {1, 8, 'latex'}

# %%
a = np.array([[1,2,3],[5,4,3]])
a
# Out:
# array([[1, 2, 3],
#        [5, 4, 3]])

# %%
a = np.matrix(a)
a
# Out:
# matrix([[1, 2, 3],
#         [5, 4, 3]])

# %%
b = np.matrix([[2],[3]])
b
# Out:
# matrix([[2],
#         [3]])

# %%
a[:2,:2]*b
# Out:
# matrix([[ 8],
#         [22]])
